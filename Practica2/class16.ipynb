# %% [markdown]
# ## Bibliotecas y lectura de datos

# %%
import numpy as np
import pandas as pd 
df = pd.read_csv("vehicles_short.csv", index_col="id")

# %% [markdown]
# ## Forma de Datos

# %%
df.head(7)
# Out:
#                                                           url  \
# id
# 7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 7210384030  https://greensboro.craigslist.org/cto/d/trinit...
# 7222379453  https://hudsonvalley.craigslist.org/cto/d/west...
# 7221952215  https://hudsonvalley.craigslist.org/cto/d/west...
#
#                             region                           region_url  \
# id
# 7222695916                prescott      https://prescott.craigslist.org
# 7218891961            fayetteville         https://fayar.craigslist.org
# 7221797935            florida keys          https://keys.craigslist.org
# 7222270760  worcester / central MA     https://worcester.craigslist.org
# 7210384030              greensboro    https://greensboro.craigslist.org
# ...

# %%
print(df.shape)
print(df.columns)
# Out:
# (42687, 25)
# Index(['url', 'region', 'region_url', 'price', 'year', 'manufacturer', 'model',
#        'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
print(df.nunique(axis=0))
df.describe().apply(lambda s: s.apply (lambda x: format (x, 'f')))
# Out:
# url             42687
# region             50
# region_url         50
# price            4113
# year              101
# manufacturer       40
# model            7399
# condition           6
# cylinders           8
# fuel                5
# odometer        19024
# title_status        6
# transmission        3
# VIN             15803
# drive               3
# size                4
# type               13
# paint_color        12
# image_url       28933
# description     36087
# county              0
# state              14
# lat              5862
# long             5914
# posting_date    40982
# dtype: int64
#                    price          year         odometer    county  \
# count       42687.000000  42472.000000     41935.000000  0.000000
# mean       166452.437463   2011.316350     97731.428282       nan
# std      17119861.242880     10.291418    300390.579029       nan
# min             0.000000   1900.000000         0.000000       nan
# ...

# %%
df.condition.unique()
#df.['condition'].unique() -> funciona igual que el de arriba
# Out:
# array([nan, 'good', 'excellent', 'fair', 'like new', 'new', 'salvage'],
#       dtype=object)

# %%
df_limpio = df.copy().drop(['url','region_url', 'image_url'], axis=1)
print(df_limpio.nunique(axis=0))

df_limpio.describe().apply(lambda s: s.apply (lambda x: format (x, 'f')))
# Out:
# region             50
# price            4113
# year              101
# manufacturer       40
# model            7399
# condition           6
# cylinders           8
# fuel                5
# odometer        19024
# title_status        6
# transmission        3
# VIN             15803
# drive               3
# size                4
# type               13
# paint_color        12
# description     36087
# county              0
# state              14
# lat              5862
# long             5914
# posting_date    40982
# dtype: int64
#                    price          year         odometer    county  \
# count       42687.000000  42472.000000     41935.000000  0.000000
# mean       166452.437463   2011.316350     97731.428282       nan
# std      17119861.242880     10.291418    300390.579029       nan
# min             0.000000   1900.000000         0.000000       nan
# 25%          6000.000000   2008.000000     33398.000000       nan
# ...

# %%
df_limpio-isna().sum()
NA_val = df_limpio.isna().sum()
def filtro_na(na, umbral=0.3): 
    col_pass=[]
    for i in na.key():
        if na[i]/df_limpio.shape[0]<umbral:
            col_pass-append(i)
    return col_pass
df_limpio = df_limpio(filtro_na(NA_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_limpio-isna().sum()
#       2 NA_val = df_limpio.isna().sum()
#       3 def filtro_na(na, umbral=0.3):
#
# NameError: name 'isna' is not defined

# %%
df_limpio.columns
# Out:
# Index(['region', 'price', 'year', 'manufacturer', 'model', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'VIN',
#        'drive', 'size', 'type', 'paint_color', 'description', 'county',
#        'state', 'lat', 'long', 'posting_date'],
#       dtype='object')

# %%
df_limpio = df_limpio[df_limpio['price'].between(200, 100000)] #Rango de 200 a 100000
df_limpio = df_limpio[df_limpio[['odometer']<200000.0]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_limpio = df_limpio[df_limpio['price'].between(200, 100000)] #Rango de 200 a 100000
# ...

# %%
# calculate correlation matrix
corr = df_cleaned.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns,
yticklabels=corr.columns, annot=True,
cmap= sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # calculate correlation matrix
# ----> 2 corr = df_cleaned.corr()# plot the heatmap
#       3 sns.heatmap(corr, xticklabels=corr.columns,
#       4 yticklabels=corr.columns, annot=True,
#       5 cmap= sns.diverging_palette(220, 20, as_cmap=True))
#
# NameError: name 'df_cleaned' is not defined

# %%
# calculate correlation matrix
corr = df_cleaned.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns,
yticklabels=corr.columns, annot=True,
cmap= sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 2
#
#       1 # calculate correlation matrix
#
# ----> 2 corr = df_cleaned.corr()# plot the heatmap
#
#       3 sns.heatmap(corr, xticklabels=corr.columns,
#
#       4 yticklabels=corr.columns, annot=True,
#
#       5 cmap= sns.diverging_palette(220, 20, as_cmap=True))
#
#
#
# NameError: name 'df_cleaned' is not defined

# %%
# calculate correlation matrix
corr = df_cleaned.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns,
yticklabels=corr.columns, annot=True,
cmap= sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[1], line 2
#
#       1 # calculate correlation matrix
#
# ----> 2 corr = df_cleaned.corr()# plot the heatmap
#
#       3 sns.heatmap(corr, xticklabels=corr.columns,
#
#       4 yticklabels=corr.columns, annot=True,
#
#       5 cmap= sns.diverging_palette(220, 20, as_cmap=True))
#
#
#
# NameError: name 'df_cleaned' is not defined
